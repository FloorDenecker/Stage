# %% [raw]
# # """
# Created on Tue Nov 20 19:33:53 2018
# alle data
# @author: beheerder
# """
# #import pandas
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
#
#
# #assign spreadsheet filename to "file"
# file = 'D:\\Users\\beheerder\\Documents\\Floor\\UGent\\2018-2019\\stage\\experiment verloop\\universiteit.xlsx'
#
# #load spreadsheet
# xl = pd.ExcelFile(file)
#
# #print the sheet names
# print(xl.sheet_names)
#
# #load a sheet into a dataframe by name
# dfu = xl.parse('Blad1')
#
# #bekijk de verschillende variabelen van de vragenlijst
# #voor elke variabele
# ### (1) gemiddelde en std
# ### (2) outliers
# ### (3) grafisch?
#
#
# ###GESLACHT: categorisch
#
# ###LEEFTIJD: categorisch
# ###TOTweek: continu
# ###TOTweekend: continu
# ### verdeling [5u - 9u (1)],[9u - 12u (2)], [12u - 13u (3)], [13u - 18u (4)], [18u - 23u (5)], [23u - 5u (6)]
# ### verdeling [internetbrower/zoek (1)], [messengers (2)], [sociale netwerksites (3)], [entertainment apps (4)], [games (5)], [andere (6)]
# ### hoe vaak tijdens auto/fiets: categorisch
# ### hoe vaak tijdens eten: categorisch
# ### hoe vaak tijdens school: categorisch
# ### min voor slapen: continu
# ### min na wakker: continu
# ### Multi1, Multi2, Multi3, Multi4, Multi5, Multi6, Multi7, Multi8, Multi9, Multi10, Multi11R, Multi12, Multi13, Multi14R
# ### MP: continu
# ### ivl anderen: categorisch
# ### gaan slapen: categorisch
# ### min tot slapen: continu
# ### opstaan: categorisch
# ### 1_1: categorisch
# ### 1_2: categorisch
# ### 1_3: categorisch
# ### 1_4: categorisch
# ### 1_5: categorisch
# ### 1_6: catgorisch
# ### 1_7: categorisch
# ### 1_8: categorisch
# ### SK: categorisch
# ### enth: categorisch
# ### SM: categorisch
# ### WB: categorisch
# ### sleepquality: continue
# ### duur laatste slaap: continu
# ### duur wakker: continu
# ### huidige vermoeidheid: categorisch
